# %%
import geopandas as gpd
import pandas as pd

# %%
osaka_geo = gpd.read_file("../data/osaka_geo/h27ka27.shp")

# %%
osaka_geo.shape
# Out:
# (8897, 36)

# %%
pd.set_option("max_columns", 40)
osaka_geo.head(10)
# Out:
#       KEY_CODE PREF CITY  S_AREA PREF_NAME CITY_NAME   S_NAME KIGO_E  HCODE  \
# 0           27   27  362  000000       大阪府       田尻町     None   None   8101
# 1  27102001001   27  102  001001       大阪府       都島区    片町１丁目   None   8101
# 2  27102001002   27  102  001002       大阪府       都島区    片町２丁目   None   8101
# 3    271020020   27  102  002000       大阪府       都島区      網島町   None   8101
# 4  27102003001   27  102  003001       大阪府       都島区  東野田町１丁目   None   8101
# 5  27102003002   27  102  003002       大阪府       都島区  東野田町２丁目   None   8101
# 6  27102003003   27  102  003003       大阪府       都島区  東野田町３丁目   None   8101
# 7  27102003004   27  102  003004       大阪府       都島区  東野田町４丁目   None   8101
# 8  27102003005   27  102  003005       大阪府       都島区  東野田町５丁目   None   8101
# 9  27102004001   27  102  004001       大阪府       都島区   中野町１丁目   None   8101
#
#          AREA  PERIMETER  H27KAxx_  H27KAxx_ID KEN KEN_NAME SITYO_NAME  \
# ...

# %%
data = pd.read_csv("../data/osaka_data/tblT000865C27.txt", encoding="shift_jis", header=[0, 1])

# %%
data[:10]
# Out:
#             KEY_CODE             HYOSYO           CITYNAME               NAME  \
#   Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1 Unnamed: 3_level_1
# 0              27102                  1             大阪市都島区                NaN
# 1          271020010                  2             大阪市都島区                 片町
# 2        27102001001                  3             大阪市都島区              片町１丁目
# 3        27102001002                  3             大阪市都島区              片町２丁目
# 4          271020020                  2             大阪市都島区                網島町
# 5          271020030                  2             大阪市都島区               東野田町
# 6        27102003001                  3             大阪市都島区            東野田町１丁目
# 7        27102003002                  3             大阪市都島区            東野田町２丁目
# 8        27102003003                  3             大阪市都島区            東野田町３丁目
# 9        27102003004                  3             大阪市都島区            東野田町４丁目
#
# ...

# %%
data.shape
# Out:
# (10572, 32)

# %%
osaka_geo["KEY_CODE"].unique()
# Out:
# array(['27', '27102001001', '27102001002', ..., '273830090', '273830100',
#        '273830110'], dtype=object)

# %%
data.columns[0]
# Out:
# ('KEY_CODE', 'Unnamed: 0_level_1')

# %%
data[data[data.columns[0]]==27102]
# Out:
#             KEY_CODE             HYOSYO           CITYNAME               NAME  \
#   Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1 Unnamed: 3_level_1
# 0              27102                  1             大阪市都島区                NaN
#
#             HTKSYORI            HTKSAKI             GASSAN T000865001  \
#   Unnamed: 4_level_1 Unnamed: 5_level_1 Unnamed: 6_level_1         総数
# 0                  0                NaN                NaN      44395
#
#   T000865002 T000865003 T000865004     T000865005 T000865006 T000865007  \
#      Ａ　農業、林業      　うち農業       Ｂ　漁業 Ｃ　鉱業、採石業、砂利採取業      Ｄ　建設業      Ｅ　製造業
# 0         28         25          1              3       2401       5505
#
#        T000865008 T000865009 T000865010 T000865011 T000865012   T000865013  \
#   Ｆ　電気・ガス・熱供給・水道業    Ｇ　情報通信業  Ｈ　運輸業、郵便業  Ｉ　卸売業、小売業  Ｊ　金融業、保険業 Ｋ　不動産業、物品賃貸業
# 0             186       2012       1844       6730       1130         1476
#
# ...

# %%
osaka_geo[osaka_geo[osaka_geo.columns[3]] == "片町"]
# Out:
# Empty GeoDataFrame
# Columns: [KEY_CODE, PREF, CITY, S_AREA, PREF_NAME, CITY_NAME, S_NAME, KIGO_E, HCODE, AREA, PERIMETER, H27KAxx_, H27KAxx_ID, KEN, KEN_NAME, SITYO_NAME, GST_NAME, CSS_NAME, KIHON1, DUMMY1, KIHON2, KEYCODE1, KEYCODE2, AREA_MAX_F, KIGO_D, N_KEN, N_CITY, KIGO_I, MOJI, KBSUM, JINKO, SETAI, X_CODE, Y_CODE, KCODE1, geometry]
# Index: []

# %%
osaka_geo[osaka_geo[osaka_geo.columns[5]] == "田尻町"]
# Out:
#        KEY_CODE PREF CITY  S_AREA PREF_NAME CITY_NAME    S_NAME KIGO_E  HCODE  \
# 0            27   27  362  000000       大阪府       田尻町      None   None   8101
# 8774  273620010   27  362  001000       大阪府       田尻町       嘉祥寺   None   8101
# 8775  273620020   27  362  002000       大阪府       田尻町        吉見   None   8101
# 8776  273620030   27  362  003000       大阪府       田尻町     泉州空港中   None   8101
# 8777  273620040   27  362  004000       大阪府       田尻町  りんくうポート北   None   8101
# 8778  273620050   27  362  005000       大阪府       田尻町  りんくうポート南   None   8101
#
#              AREA  PERIMETER  H27KAxx_  H27KAxx_ID KEN KEN_NAME SITYO_NAME  \
# 0       75144.542   1311.122      5891        5890  27      大阪府       None
# 8774   922762.224   6194.290      6465        6464  27      大阪府       None
# 8775   955775.424   5464.852      8458        8457  27      大阪府       None
# 8776  2630875.566  11459.680      4767        4766  27      大阪府       None
# ...

# %%
data[data.columns[2]].unique()
# Out:
# array(['大阪市都島区', '大阪市福島区', '大阪市此花区', '大阪市西区', '大阪市港区', '大阪市大正区',
#        '大阪市天王寺区', '大阪市浪速区', '大阪市西淀川区', '大阪市東淀川区', '大阪市東成区', '大阪市生野区',
#        '大阪市旭区', '大阪市城東区', '大阪市阿倍野区', '大阪市住吉区', '大阪市東住吉区', '大阪市西成区',
#        '大阪市淀川区', '大阪市鶴見区', '大阪市住之江区', '大阪市平野区', '大阪市北区', '大阪市中央区', '堺市堺区',
#        '堺市中区', '堺市東区', '堺市西区', '堺市南区', '堺市北区', '堺市美原区', '岸和田市', '豊中市',
#        '池田市', '吹田市', '泉大津市', '高槻市', '貝塚市', '守口市', '枚方市', '茨木市', '八尾市',
#        '泉佐野市', '富田林市', '寝屋川市', '河内長野市', '松原市', '大東市', '和泉市', '箕面市', '柏原市',
#        '羽曳野市', '門真市', '摂津市', '高石市', '藤井寺市', '東大阪市', '泉南市', '四條畷市', '交野市',
#        '大阪狭山市', '阪南市', '三島郡島本町', '豊能郡豊能町', '豊能郡能勢町', '泉北郡忠岡町', '泉南郡熊取町',
#        '泉南郡田尻町', '泉南郡岬町', '南河内郡太子町', '南河内郡河南町', '南河内郡千早赤阪村'], dtype=object)

# %%
data[data[data.columns[2]] == '泉南郡田尻町']
# Out:
#                 KEY_CODE             HYOSYO           CITYNAME  \
#       Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1
# 10444              27362                  1             泉南郡田尻町
# 10445          273620010                  2             泉南郡田尻町
# 10446          273620020                  2             泉南郡田尻町
# 10447          273620030                  2             泉南郡田尻町
# 10448          273620040                  2             泉南郡田尻町
# 10449          273620050                  2             泉南郡田尻町
#
#                     NAME           HTKSYORI            HTKSAKI  \
#       Unnamed: 3_level_1 Unnamed: 4_level_1 Unnamed: 5_level_1
# 10444                NaN                  0                NaN
# 10445                嘉祥寺                  0                NaN
# 10446                 吉見                  1                NaN
# 10447              泉州空港中                  2               20.0
# 10448           りんくうポート北                  0                NaN
# ...

# %%
data[data[data.columns[2]] == "大阪市都島区"]
# Out:
#              KEY_CODE             HYOSYO           CITYNAME  \
#    Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1
# 0               27102                  1             大阪市都島区
# 1           271020010                  2             大阪市都島区
# 2         27102001001                  3             大阪市都島区
# 3         27102001002                  3             大阪市都島区
# 4           271020020                  2             大阪市都島区
# ..                ...                ...                ...
# 57        27102015001                  3             大阪市都島区
# 58        27102015002                  3             大阪市都島区
# 59        27102015003                  3             大阪市都島区
# 60        27102015004                  3             大阪市都島区
# 61        27102015005                  3             大阪市都島区
#
#                  NAME           HTKSYORI            HTKSAKI  \
#    Unnamed: 3_level_1 Unnamed: 4_level_1 Unnamed: 5_level_1
# 0                 NaN                  0                NaN
# ...

# %%
osaka_geo["S_NAME"] = osaka_geo["S_NAME"].fillna(0)

# %%
osaka_geo[osaka_geo["S_NAME"]==0]
# Out:
#       KEY_CODE PREF CITY  S_AREA PREF_NAME CITY_NAME S_NAME KIGO_E  HCODE  \
# 0           27   27  362  000000       大阪府       田尻町      0   None   8101
# 149  271041000   27  104  100000       大阪府       此花区      0   None   8154
# 267  271071000   27  107  100000       大阪府        港区      0   None   8154
# 316  271081000   27  108  100000       大阪府       大正区      0   None   8154
# 513  271131000   27  113  100000       大阪府      西淀川区      0   None   8154
#
#              AREA  PERIMETER  H27KAxx_  H27KAxx_ID KEN KEN_NAME SITYO_NAME  \
# 0    7.514454e+04   1311.122      5891        5890  27      大阪府       None
# 149  1.321406e+07  56324.244      8897        8896  27      大阪府       None
# 267  3.323573e+06  37999.074      8891        8890  27      大阪府       None
# 316  2.430999e+06  29353.412      8895        8894  27      大阪府       None
# 513  2.737339e+06  13091.428      8894        8893  27      大阪府       None
#
# ...

# %%
data[data[data.columns[1]]==3].iloc[0, 0]
# Out:
# 27102001001

# %%
type(data[data[data.columns[1]]==3].iloc[0, 0])
# Out:
# numpy.int64

# %%
len(str(data[data[data.columns[1]]==3].iloc[0, 0]))
# Out:
# 11

# %%
data[data[data.columns[1]]==2].iloc[0, 0]
# Out:
# 271020010

# %%
len(str(data[data[data.columns[1]]==2].iloc[0, 0]))
# Out:
# 9

# %%
data[data[data.columns[1]]==1].iloc[0, 0]
# Out:
# 27102

# %%
len(str(data[data[data.columns[1]]==1].iloc[0, 0]))
# Out:
# 5

# %%
str(data[data[data.columns[1]]==1].iloc[0, 0]).ljust(11, "0")
# Out:
# '27102000000'

# %%
len(str(data[data[data.columns[1]]==1].iloc[0, 0]).ljust(11, "0"))
# Out:
# 11

# %%
data.columns[0]
# Out:
# ('KEY_CODE', 'Unnamed: 0_level_1')

# %%
data[("KEY_C", "KEY_C")] = str(data[data.columns[0]]).ljust(11, "0")

# %%
data.columns.get_level_values(0)
# Out:
# Index(['KEY_CODE', 'HYOSYO', 'CITYNAME', 'NAME', 'HTKSYORI', 'HTKSAKI',
#        'GASSAN', 'T000865001', 'T000865002', 'T000865003', 'T000865004',
#        'T000865005', 'T000865006', 'T000865007', 'T000865008', 'T000865009',
#        'T000865010', 'T000865011', 'T000865012', 'T000865013', 'T000865014',
#        'T000865015', 'T000865016', 'T000865017', 'T000865018', 'T000865019',
#        'T000865020', 'T000865021', 'T000865022', 'T000865023', 'T000865024',
#        'T000865025', 'KEY_C'],
#       dtype='object')

# %%
data.columns.get_level_values(1)
# Out:
# Index(['Unnamed: 0_level_1', 'Unnamed: 1_level_1', 'Unnamed: 2_level_1',
#        'Unnamed: 3_level_1', 'Unnamed: 4_level_1', 'Unnamed: 5_level_1',
#        'Unnamed: 6_level_1', '総数', 'Ａ　農業、林業', '　うち農業', 'Ｂ　漁業',
#        'Ｃ　鉱業、採石業、砂利採取業', 'Ｄ　建設業', 'Ｅ　製造業', 'Ｆ　電気・ガス・熱供給・水道業', 'Ｇ　情報通信業',
#        'Ｈ　運輸業、郵便業', 'Ｉ　卸売業、小売業', 'Ｊ　金融業、保険業', 'Ｋ　不動産業、物品賃貸業',
#        'Ｌ　学術研究、専門・技術サービス業', 'Ｍ　宿泊業、飲食サービス業', 'Ｎ　生活関連サービス業、娯楽業', 'Ｏ　教育、学習支援業',
#        'Ｐ　医療、福祉', 'Ｑ　複合サービス事業', 'Ｒ　サービス業（他に分類されないもの）', 'Ｓ　公務（他に分類されるものを除く）',
#        'Ｔ　分類不能の産業', '雇用者（役員を含む）', '自営業主（家庭内職者を含む）', '家族従業者', 'KEY_C'],
#       dtype='object')

# %%
list(data.columns.get_level_values(0)[:7]) + list(data.columns.get_level_values(1)[7:])
# Out:
# ['KEY_CODE',
#  'HYOSYO',
#  'CITYNAME',
#  'NAME',
#  'HTKSYORI',
#  'HTKSAKI',
#  'GASSAN',
#  '総数',
#  'Ａ\u3000農業、林業',
#  '\u3000うち農業',
#  'Ｂ\u3000漁業',
#  'Ｃ\u3000鉱業、採石業、砂利採取業',
#  'Ｄ\u3000建設業',
#  'Ｅ\u3000製造業',
#  'Ｆ\u3000電気・ガス・熱供給・水道業',
#  'Ｇ\u3000情報通信業',
#  'Ｈ\u3000運輸業、郵便業',
#  'Ｉ\u3000卸売業、小売業',
#  'Ｊ\u3000金融業、保険業',
#  'Ｋ\u3000不動産業、物品賃貸業',
#  'Ｌ\u3000学術研究、専門・技術サービス業',
#  'Ｍ\u3000宿泊業、飲食サービス業',
#  'Ｎ\u3000生活関連サービス業、娯楽業',
#  'Ｏ\u3000教育、学習支援業',
#  'Ｐ\u3000医療、福祉',
#  'Ｑ\u3000複合サービス事業',
#  'Ｒ\u3000サービス業（他に分類されないもの）',
#  'Ｓ\u3000公務（他に分類されるものを除く）',
#  'Ｔ\u3000分類不能の産業',
#  '雇用者（役員を含む）',
#  '自営業主（家庭内職者を含む）',
#  '家族従業者',
#  'KEY_C']

# %%
cols_name = list(data.columns.get_level_values(0)[:7]) + list(data.columns.get_level_values(1)[7:])
data.columns = cols_name

# %%
data.head()
# Out:
#       KEY_CODE  HYOSYO CITYNAME   NAME  HTKSYORI  HTKSAKI GASSAN     総数  \
# 0        27102       1   大阪市都島区    NaN         0      NaN    NaN  44395
# 1    271020010       2   大阪市都島区     片町         0      NaN    NaN   1029
# 2  27102001001       3   大阪市都島区  片町１丁目         0      NaN    NaN    684
# 3  27102001002       3   大阪市都島区  片町２丁目         0      NaN    NaN    345
# 4    271020020       2   大阪市都島区    網島町         0      NaN    NaN    566
#
#   Ａ　農業、林業 　うち農業 Ｂ　漁業 Ｃ　鉱業、採石業、砂利採取業 Ｄ　建設業 Ｅ　製造業 Ｆ　電気・ガス・熱供給・水道業 Ｇ　情報通信業  \
# 0      28    25    1              3  2401  5505             186    2012
# 1       2     2    -              -    44   120               4      75
# 2       1     1    -              -    28    61               3      53
# 3       1     1    -              -    16    59               1      22
# 4       -     -    -              -    14    61               4      37
#
#   Ｈ　運輸業、郵便業 Ｉ　卸売業、小売業 Ｊ　金融業、保険業 Ｋ　不動産業、物品賃貸業 Ｌ　学術研究、専門・技術サービス業 Ｍ　宿泊業、飲食サービス業  \
# ...

# %%
data["KEY_C"] = data["KEY_CODE"].apply(lambda x: str(x).ljust(11, "0"))

# %%
data
# Out:
#           KEY_CODE  HYOSYO   CITYNAME   NAME  HTKSYORI  HTKSAKI GASSAN     総数  \
# 0            27102       1     大阪市都島区    NaN         0      NaN    NaN  44395
# 1        271020010       2     大阪市都島区     片町         0      NaN    NaN   1029
# 2      27102001001       3     大阪市都島区  片町１丁目         0      NaN    NaN    684
# 3      27102001002       3     大阪市都島区  片町２丁目         0      NaN    NaN    345
# 4        271020020       2     大阪市都島区    網島町         0      NaN    NaN    566
# ...            ...     ...        ...    ...       ...      ...    ...    ...
# 10567  27383007001       3  南河内郡千早赤阪村   大字小吹         0      NaN    NaN    129
# 10568  27383007002       3  南河内郡千早赤阪村   大字小吹         0      NaN    NaN    723
# 10569    273830090       2  南河内郡千早赤阪村  大字中津原         0      NaN    NaN    116
# 10570    273830100       2  南河内郡千早赤阪村   大字東阪         0      NaN    NaN    192
# 10571    273830110       2  南河内郡千早赤阪村   大字千早         0      NaN    NaN     96
#
# ...

# %%
osaka_geo.head()
# Out:
#       KEY_CODE PREF CITY  S_AREA PREF_NAME CITY_NAME   S_NAME KIGO_E  HCODE  \
# 0           27   27  362  000000       大阪府       田尻町        0   None   8101
# 1  27102001001   27  102  001001       大阪府       都島区    片町１丁目   None   8101
# 2  27102001002   27  102  001002       大阪府       都島区    片町２丁目   None   8101
# 3    271020020   27  102  002000       大阪府       都島区      網島町   None   8101
# 4  27102003001   27  102  003001       大阪府       都島区  東野田町１丁目   None   8101
#
#          AREA  PERIMETER  H27KAxx_  H27KAxx_ID KEN KEN_NAME SITYO_NAME  \
# 0   75144.542   1311.122      5891        5890  27      大阪府       None
# 1  102717.012   1667.307      2171        2170  27      大阪府       None
# 2  127975.845   1780.858      6766        6765  27      大阪府       None
# 3  191219.722   2060.096      8250        8249  27      大阪府       None
# 4  105965.787   1327.310       523         522  27      大阪府       None
#
#   GST_NAME CSS_NAME KIHON1 DUMMY1 KIHON2   KEYCODE1   KEYCODE2 AREA_MAX_F  \
# ...

# %%
osaka_geo["KEY_C"] = osaka_geo["PREF"].astype(str) + osaka_geo["CITY"].astype(str) + osaka_geo["S_AREA"].astype(str)

# %%
osaka_geo.tail()
# Out:
#          KEY_CODE PREF CITY  S_AREA PREF_NAME CITY_NAME S_NAME KIGO_E  HCODE  \
# 8892  27383007001   27  383  007001       大阪府     千早赤阪村   大字小吹   None   8101
# 8893  27383007002   27  383  007002       大阪府     千早赤阪村   大字小吹   None   8101
# 8894    273830090   27  383  009000       大阪府     千早赤阪村  大字中津原   None   8101
# 8895    273830100   27  383  010000       大阪府     千早赤阪村   大字東阪   None   8101
# 8896    273830110   27  383  011000       大阪府     千早赤阪村   大字千早   None   8101
#
#              AREA  PERIMETER  H27KAxx_  H27KAxx_ID KEN KEN_NAME SITYO_NAME  \
# 8892  1941696.772   8350.971      2581        2580  27      大阪府       None
# 8893   362713.847   3416.303      6077        6076  27      大阪府       None
# 8894  2504907.178   8612.457      6074        6073  27      大阪府       None
# 8895  4121487.802  20583.320      1879        1878  27      大阪府       None
# 8896  8623739.338  14893.256      5900        5899  27      大阪府       None
#
# ...

# %%
test_osaka = osaka_geo.merge(data, left_on="KEY_C", right_on="KEY_C")

# %%
pd.set_option("max_columns", 80)
test_osaka.head()
# Out:
#     KEY_CODE_x PREF CITY  S_AREA PREF_NAME CITY_NAME   S_NAME KIGO_E  HCODE  \
# 0           27   27  362  000000       大阪府       田尻町        0   None   8101
# 1  27102001001   27  102  001001       大阪府       都島区    片町１丁目   None   8101
# 2  27102001002   27  102  001002       大阪府       都島区    片町２丁目   None   8101
# 3    271020020   27  102  002000       大阪府       都島区      網島町   None   8101
# 4  27102003001   27  102  003001       大阪府       都島区  東野田町１丁目   None   8101
#
#          AREA  PERIMETER  H27KAxx_  H27KAxx_ID KEN KEN_NAME SITYO_NAME  \
# 0   75144.542   1311.122      5891        5890  27      大阪府       None
# 1  102717.012   1667.307      2171        2170  27      大阪府       None
# 2  127975.845   1780.858      6766        6765  27      大阪府       None
# 3  191219.722   2060.096      8250        8249  27      大阪府       None
# 4  105965.787   1327.310       523         522  27      大阪府       None
#
#   GST_NAME CSS_NAME KIHON1 DUMMY1 KIHON2   KEYCODE1   KEYCODE2 AREA_MAX_F  \
# ...

# %%
test_osaka.shape
# Out:
# (8903, 69)

# %%
test_osaka["KEY_C"].value_counts()
# Out:
# 27361055000    14
# 27219301000    10
# 27222045000     8
# 27206031000     7
# 27222025000     6
#                ..
# 27366002013     1
# 27111015001     1
# 27220035006     1
# 27215313000     1
# 27113011005     1
# Name: KEY_C, Length: 8661, dtype: int64

# %%
osaka_geo["KEY_C"].value_counts()
# Out:
# 27361055000    14
# 27222045000     8
# 27206031000     7
# 27143004000     6
# 27206047003     5
#                ..
# 27141081000     1
# 27205007003     1
# 27217010004     1
# 27212058005     1
# 27113011005     1
# Name: KEY_C, Length: 8693, dtype: int64

# %%
len(data["KEY_C"].value_counts()[data["KEY_C"].value_counts().values == 2])
# Out:
# 31

# %%
data["KEY_C"].value_counts()[data["KEY_C"].value_counts().values == 2]
# Out:
# 27222025000    2
# 27224023000    2
# 27208004000    2
# 27206058000    2
# 27208006000    2
# 27143012000    2
# 27202123200    2
# 27228005000    2
# 27219101000    2
# 27145029000    2
# 27222031000    2
# 27224017000    2
# 27232021000    2
# 27220001000    2
# 27202045100    2
# 27213038000    2
# 27219302000    2
# 27202097000    2
# 27213039000    2
# 27232001000    2
# 27146012000    2
# 27220009000    2
# 27208014000    2
# 27219301000    2
# 27222014000    2
# 27224020000    2
# 27228001000    2
# 27210157000    2
# 27222021000    2
# 27208060000    2
# 27232036000    2
# Name: KEY_C, dtype: int64

# %%
osaka_geo[osaka_geo["KEY_C"] == "27361055000"]
# Out:
#        KEY_CODE PREF CITY  S_AREA PREF_NAME CITY_NAME S_NAME KIGO_E  HCODE  \
# 8729  273610550   27  361  055000       大阪府       熊取町    七山北     E1   8101
# 8730  273610550   27  361  055000       大阪府       熊取町    七山北    E10   8101
# 8731  273610550   27  361  055000       大阪府       熊取町    七山北    E11   8101
# 8732  273610550   27  361  055000       大阪府       熊取町    七山北    E12   8101
# 8733  273610550   27  361  055000       大阪府       熊取町    七山北    E13   8101
# 8734  273610550   27  361  055000       大阪府       熊取町    七山北    E14   8101
# 8735  273610550   27  361  055000       大阪府       熊取町    七山北     E2   8101
# 8736  273610550   27  361  055000       大阪府       熊取町    七山北     E3   8101
# 8737  273610550   27  361  055000       大阪府       熊取町    七山北     E4   8101
# 8738  273610550   27  361  055000       大阪府       熊取町    七山北     E5   8101
# 8739  273610550   27  361  055000       大阪府       熊取町    七山北     E6   8101
# ...

# %%
osaka_geo[osaka_geo["KEY_C"] == "27222045000"]
# Out:
#        KEY_CODE PREF CITY  S_AREA PREF_NAME CITY_NAME S_NAME KIGO_E  HCODE  \
# 7176  272220450   27  222  045000       大阪府      羽曳野市     壷井     E1   8101
# 7177  272220450   27  222  045000       大阪府      羽曳野市     壷井     E2   8101
# 7178  272220450   27  222  045000       大阪府      羽曳野市     壷井     E3   8101
# 7179  272220450   27  222  045000       大阪府      羽曳野市     壷井     E4   8101
# 7180  272220450   27  222  045000       大阪府      羽曳野市     壷井     E5   8101
# 7181  272220450   27  222  045000       大阪府      羽曳野市     壷井     E6   8101
# 7182  272220450   27  222  045000       大阪府      羽曳野市     壷井     E7   8101
# 7183  272220450   27  222  045000       大阪府      羽曳野市     壷井     E8   8101
#
#             AREA  PERIMETER  H27KAxx_  H27KAxx_ID KEN KEN_NAME SITYO_NAME  \
# 7176   23055.079    907.805      8633        8632  27      大阪府       None
# 7177  772942.024   6159.651      8634        8633  27      大阪府       None
# ...

# %%
data[data["KEY_C"] == "27222045000"]
# Out:
#        KEY_CODE  HYOSYO CITYNAME NAME  HTKSYORI  HTKSAKI GASSAN   総数 Ａ　農業、林業  \
# 8586  272220450       2     羽曳野市   壷井         0      NaN    NaN  254       4
#
#      　うち農業 Ｂ　漁業 Ｃ　鉱業、採石業、砂利採取業 Ｄ　建設業 Ｅ　製造業 Ｆ　電気・ガス・熱供給・水道業 Ｇ　情報通信業 Ｈ　運輸業、郵便業  \
# 8586     4    -              -    29    61               1       3        15
#
#      Ｉ　卸売業、小売業 Ｊ　金融業、保険業 Ｋ　不動産業、物品賃貸業 Ｌ　学術研究、専門・技術サービス業 Ｍ　宿泊業、飲食サービス業  \
# 8586        30         4            3                 5            13
#
#      Ｎ　生活関連サービス業、娯楽業 Ｏ　教育、学習支援業 Ｐ　医療、福祉 Ｑ　複合サービス事業 Ｒ　サービス業（他に分類されないもの）  \
# 8586               6          8      35          -                  15
#
#      Ｓ　公務（他に分類されるものを除く） Ｔ　分類不能の産業 雇用者（役員を含む） 自営業主（家庭内職者を含む） 家族従業者        KEY_C
# 8586                  9        13        212             25    10  27222045000

# %%
data[data["KEY_CODE"] == 272220450]
# Out:
#        KEY_CODE  HYOSYO CITYNAME NAME  HTKSYORI  HTKSAKI GASSAN   総数 Ａ　農業、林業  \
# 8586  272220450       2     羽曳野市   壷井         0      NaN    NaN  254       4
#
#      　うち農業 Ｂ　漁業 Ｃ　鉱業、採石業、砂利採取業 Ｄ　建設業 Ｅ　製造業 Ｆ　電気・ガス・熱供給・水道業 Ｇ　情報通信業 Ｈ　運輸業、郵便業  \
# 8586     4    -              -    29    61               1       3        15
#
#      Ｉ　卸売業、小売業 Ｊ　金融業、保険業 Ｋ　不動産業、物品賃貸業 Ｌ　学術研究、専門・技術サービス業 Ｍ　宿泊業、飲食サービス業  \
# 8586        30         4            3                 5            13
#
#      Ｎ　生活関連サービス業、娯楽業 Ｏ　教育、学習支援業 Ｐ　医療、福祉 Ｑ　複合サービス事業 Ｒ　サービス業（他に分類されないもの）  \
# 8586               6          8      35          -                  15
#
#      Ｓ　公務（他に分類されるものを除く） Ｔ　分類不能の産業 雇用者（役員を含む） 自営業主（家庭内職者を含む） 家族従業者        KEY_C
# 8586                  9        13        212             25    10  27222045000

# %%
data[data["KEY_C"] == "27222025000"]
# Out:
#          KEY_CODE  HYOSYO CITYNAME NAME  HTKSYORI  HTKSAKI GASSAN   総数  \
# 8557    272220250       2     羽曳野市   向野         0      NaN    NaN  814
# 8558  27222025000       3     羽曳野市   向野         0      NaN    NaN  147
#
#      Ａ　農業、林業 　うち農業 Ｂ　漁業 Ｃ　鉱業、採石業、砂利採取業 Ｄ　建設業 Ｅ　製造業 Ｆ　電気・ガス・熱供給・水道業 Ｇ　情報通信業  \
# 8557       3     3    -              -    45   139               -       7
# 8558       1     1    -              -    10    33               -       1
#
#      Ｈ　運輸業、郵便業 Ｉ　卸売業、小売業 Ｊ　金融業、保険業 Ｋ　不動産業、物品賃貸業 Ｌ　学術研究、専門・技術サービス業  \
# 8557        50       216         5           19                 7
# 8558        13        27         -            2                 2
#
#      Ｍ　宿泊業、飲食サービス業 Ｎ　生活関連サービス業、娯楽業 Ｏ　教育、学習支援業 Ｐ　医療、福祉 Ｑ　複合サービス事業  \
# 8557            46              29         15      99          1
# 8558             7               7          2      25          -
#
#      Ｒ　サービス業（他に分類されないもの） Ｓ　公務（他に分類されるものを除く） Ｔ　分類不能の産業 雇用者（役員を含む）  \
# ...

# %%
osaka_geo[osaka_geo["KEY_C"] == "27222025000"]
# Out:
#          KEY_CODE PREF CITY  S_AREA PREF_NAME CITY_NAME S_NAME KIGO_E  HCODE  \
# 7142  27222025000   27  222  025000       大阪府      羽曳野市     向野     E1   8101
# 7143  27222025000   27  222  025000       大阪府      羽曳野市     向野     E2   8101
# 7144  27222025000   27  222  025000       大阪府      羽曳野市     向野     E3   8101
#
#            AREA  PERIMETER  H27KAxx_  H27KAxx_ID KEN KEN_NAME SITYO_NAME  \
# 7142  19401.282   1018.917      4284        4283  27      大阪府       None
# 7143  16561.083    614.340      4286        4285  27      大阪府       None
# 7144  15020.858    566.384      4285        4284  27      大阪府       None
#
#      GST_NAME CSS_NAME KIHON1 DUMMY1 KIHON2   KEYCODE1   KEYCODE2 AREA_MAX_F  \
# 7142     羽曳野市     None   0250      -     00  222025000  222025000          M
# 7143     羽曳野市     None   0250      -     00  222025000  222025000       None
# 7144     羽曳野市     None   0250      -     00  222025000  222025000       None
#
# ...

# %%
osaka_geo[osaka_geo["KEY_CODE"] == 272220250]
# Out:
# Empty GeoDataFrame
# Columns: [KEY_CODE, PREF, CITY, S_AREA, PREF_NAME, CITY_NAME, S_NAME, KIGO_E, HCODE, AREA, PERIMETER, H27KAxx_, H27KAxx_ID, KEN, KEN_NAME, SITYO_NAME, GST_NAME, CSS_NAME, KIHON1, DUMMY1, KIHON2, KEYCODE1, KEYCODE2, AREA_MAX_F, KIGO_D, N_KEN, N_CITY, KIGO_I, MOJI, KBSUM, JINKO, SETAI, X_CODE, Y_CODE, KCODE1, geometry, KEY_C]
# Index: []

# %%
osaka_geo[osaka_geo["S_NAME"] == "向野"]
# Out:
#          KEY_CODE PREF CITY  S_AREA PREF_NAME CITY_NAME S_NAME KIGO_E  HCODE  \
# 7142  27222025000   27  222  025000       大阪府      羽曳野市     向野     E1   8101
# 7143  27222025000   27  222  025000       大阪府      羽曳野市     向野     E2   8101
# 7144  27222025000   27  222  025000       大阪府      羽曳野市     向野     E3   8101
#
#            AREA  PERIMETER  H27KAxx_  H27KAxx_ID KEN KEN_NAME SITYO_NAME  \
# 7142  19401.282   1018.917      4284        4283  27      大阪府       None
# 7143  16561.083    614.340      4286        4285  27      大阪府       None
# 7144  15020.858    566.384      4285        4284  27      大阪府       None
#
#      GST_NAME CSS_NAME KIHON1 DUMMY1 KIHON2   KEYCODE1   KEYCODE2 AREA_MAX_F  \
# 7142     羽曳野市     None   0250      -     00  222025000  222025000          M
# 7143     羽曳野市     None   0250      -     00  222025000  222025000       None
# 7144     羽曳野市     None   0250      -     00  222025000  222025000       None
#
# ...

# %%
test_0723 = osaka_geo[osaka_geo["KEY_C"] == "27222025000"]
test_0723.iloc[0, -2]

# %%
test_0723.iloc[1, -2]

# %%
test_0723.iloc[2, -2]

# %%
import folium

# %%
# !pip install folium
# Out:
# ...
#   Using cached folium-0.11.0-py2.py3-none-any.whl (93 kB)
# ...
#   Using cached branca-0.4.1-py3-none-any.whl (24 kB)
# ...

# %%
m = folium.Map([test_0723.iloc[0, -4], test_0723.iloc[0,-5]], zoom_start=15)
folium.GeoJson(test_0723.iloc[0, -2]).add_to(m)
folium.GeoJson(test_0723.iloc[1, -2]).add_to(m)
folium.GeoJson(test_0723.iloc[2, -2]).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

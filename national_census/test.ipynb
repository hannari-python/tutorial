# %%
import geopandas as gpd
from zipfile import ZipFile
import pandas as pd

# %%
with ZipFile("../data/tblT000866C01.zip") as myzip:
    myzip.extractall()

# %%
df = pd.read_csv('tblT000866C01.txt', encoding="cp932", header=[0,1])

# %%
df[:100]
# Out:
#              KEY_CODE             HYOSYO           CITYNAME  \
#    Unnamed: 0_level_1 Unnamed: 1_level_1 Unnamed: 2_level_1
# 0                1101                  1             札幌市中央区
# 1            11010200                  2             札幌市中央区
# 2            11010300                  2             札幌市中央区
# 3            11010400                  2             札幌市中央区
# 4            11011000                  2             札幌市中央区
# ..                ...                ...                ...
# 95         1101170001                  3             札幌市中央区
# 96         1101170002                  3             札幌市中央区
# 97         1101170003                  3             札幌市中央区
# 98         1101170004                  3             札幌市中央区
# 99         1101170005                  3             札幌市中央区
#
#                  NAME           HTKSYORI            HTKSAKI  \
#    Unnamed: 3_level_1 Unnamed: 4_level_1 Unnamed: 5_level_1
# 0                 NaN                  0                NaN
# ...

# %%
print(df.columns[2])
print(df.columns[7])
# Out:
# ('CITYNAME', 'Unnamed: 2_level_1')
# ('T000866001', '総数')

# %%
import plotly.graph_objects as go
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-21-6f81d4723060> in <module>
# ----> 1 import plotly.graph_objects as go
#
# ModuleNotFoundError: No module named 'plotly'

# %%
df.loc[:, ('CITYNAME', 'Unnamed: 2_level_1')]
# Out:
# 0          札幌市中央区
# 1          札幌市中央区
# 2          札幌市中央区
# 3          札幌市中央区
# 4          札幌市中央区
#            ...
# 25650    根室振興局羅臼町
# 25651    根室振興局羅臼町
# 25652    根室振興局羅臼町
# 25653    根室振興局羅臼町
# 25654    根室振興局羅臼町
# Name: (CITYNAME, Unnamed: 2_level_1), Length: 25655, dtype: object

# %%
df.loc[:, ('T000866001', '総数')].plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-25-29ed0b840f70> in <module>
# ----> 1 df.loc[:, ('T000866001', '総数')].plot()
#
# /mnt/c/Users/hogaw/documents/pyconjp/ubu/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     765
#     766     def __call__(self, *args, **kwargs):
# --> 767         plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     768
#     769         x, y, kind, kwargs = self._get_call_args(
#
# /mnt/c/Users/hogaw/documents/pyconjp/ubu/lib/python3.8/site-packages/pandas/plotting/_core.py in _get_plot_backend(backend)
#    1664             import pandas.plotting._matplotlib as module
#    1665         except ImportError:
# -> 1666             raise ImportError(
#    1667                 "matplotlib is required for plotting when the "
# ...

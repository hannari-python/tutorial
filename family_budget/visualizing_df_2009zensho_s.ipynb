# %% [markdown]
# <a href="https://colab.research.google.com/github/hannari-python/tutorial/blob/master/household/visualizing_df_2009zensho_s.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://github.com/hannari-python/tutorial/raw/master/data/ippan-microdata/ippan_2009zensho_s.zip

# %%
# !unzip ippan_2009zensho_s.zip

# %%
import pandas as pd
zen_xls = pd.read_excel("ippan_2009zensho_s/ippan_2009zensho_s.xls")

# %%
zen_xls

# %%
df_2009zensho_s = pd.read_csv("ippan_2009zensho_s/ippan_2009zensho_s_dataset.csv", encoding="shift_jis")

# %%
df_2009zensho_s.head(n=20)
# Out:
#          ※一般用ミクロデータは、公表済みの結果表から作成したミクロデータ形式のデータセットです。  ...         981
# 0      　このため、一般用ミクロデータから導かれた分析結果は実証研究の結果とみなすことはできません。  ...      他    の
# 1   ※注意事項など、一般用ミクロデータの最新情報は、統計センターＨＰ（http://www.ns...  ...        仕送り金
# 2                                 　ご利用いただく前にはご確認ください。  ...         NaN
# 3                                                 NaN  ...         NaN
# 4                                                 NaN  ...         NaN
# 5                                                 NaN  ...       Other
# 6                                                 NaN  ...  remittance
# 7                                               3City  ...        E410
# 8                                                   1  ...         390
# 9                                                   1  ...         188
# 10                                                  1  ...         246
# 11                                                  1  ...         151
# ...

# %%
df_2009zensho_s = pd.read_csv("ippan_2009zensho_s/ippan_2009zensho_s_dataset.csv", encoding="shift_jis", skiprows=8)

# %%
df_2009zensho_s.head()
# Out:
#    3City  T_SeJinin  T_SyuJinin  T_JuSyoyu  ...  E407  E408  E409  E410
# 0      1          2           1          1  ...  1141   576   186   390
# 1      1          2           1          1  ...   348   282    94   188
# 2      1          2           1          1  ...   658   429   183   246
# 3      1          2           1          1  ...   445   205    55   151
# 4      1          2           1          1  ...   428   445   138   307
#
# [5 rows x 430 columns]

# %%
df_2009zensho_s.isnull().sum().sort_values(ascending = False)
# Out:
# E410     0
# E115     0
# E117     0
# E118     0
# E119     0
#         ..
# E270     0
# E271     0
# E272     0
# E273     0
# 3City    0
# Length: 430, dtype: int64

# %%
df_2009zensho_s.isna().sum().sort_values(ascending = False)
# Out:
# E410     0
# E115     0
# E117     0
# E118     0
# E119     0
#         ..
# E270     0
# E271     0
# E272     0
# E273     0
# 3City    0
# Length: 430, dtype: int64

# %%
df_2009zensho_s.isnull().any().any()
# Out:
# False

# %%
df_2009zensho_s.isnull().values.sum()
# Out:
# 0

# %%
df_2009zensho_s.isnull().any()
# Out:
# 3City         False
# T_SeJinin     False
# T_SyuJinin    False
# T_JuSyoyu     False
# T_Syuhi       False
#               ...
# E406          False
# E407          False
# E408          False
# E409          False
# E410          False
# Length: 430, dtype: bool
